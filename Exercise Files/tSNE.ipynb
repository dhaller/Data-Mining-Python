# %% [markdown]
# # t-SNE: t-DISTRIBUTED STOCHASTIC NEIGHBOR EMBEDDING
#
# **File:** tSNE.ipynb
#
# **Course:** Data Science Foundations: Data Mining in Python

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd                # For dataframe
import matplotlib.pyplot as plt    # For plotting data
import seaborn as sns              # For plotting data
from sklearn.manifold import TSNE  # For tSNE

# %% [markdown]
# # LOAD AND PREPARE DATA
#
# Load the complete dataset (as opposed to the training or testing data) from the CSV file in the data directory. Separate the data matrix from the class variable. Name the data matrix as `df` and the column with class labels as `y`.

# %%
# Imports the complete dataset
df = pd.read_csv('data/optdigits.csv')

# Separates the attributes P0-P63 into X
X = df.filter(regex='\d')

# Separates the class variable into y
y = df.y

# %%
# Shows the first few rows of the data
df.head()
# Out:
#    P0  P1  P2  P3  P4  P5  P6  P7  P8  P9  ...  P55  P56  P57  P58  P59  P60  \
# 0   0   0   5  14   4   0   0   0   0   0  ...    0    0    0    4   12   14
# 1   0   0   0   3  16  11   1   0   0   0  ...    0    0    0    0    2   14
# 2   0   0   7  11  11   6   0   0   0   9  ...    0    0    0   14   16   12
# 3   0   0   9  13   1   0   0   0   0   0  ...    5    0    0    4   15   16
# 4   0   0   0  10  12   0   0   0   0   0  ...    0    0    0    1   11   14
#
#    P61  P62  P63  y
# 0    7    0    0  6
# 1   14    1    0  1
# 2   10    1    0  3
# 3   16   16   16  1
# 4   12    1    0  6
#
# [5 rows x 65 columns]

# %% [markdown]
# # t-SNE: MODEL DATA
#
# This phase applies t-SNE to the training data with various values of the perplexity parameter and displays embeddings of data.

# %%
# Sets up the t-SNE object with 2 components
tsne = TSNE(
    n_components=2,
    random_state=1)

# %%
# Displays the t-SNE parameters
tsne.get_params()
# Out:
# {'angle': 0.5,
#  'early_exaggeration': 12.0,
#  'init': 'pca',
#  'learning_rate': 'auto',
#  'method': 'barnes_hut',
#  'metric': 'euclidean',
#  'metric_params': None,
#  'min_grad_norm': 1e-07,
#  'n_components': 2,
#  'n_iter': 1000,
#  'n_iter_without_progress': 300,
#  'n_jobs': None,
#  'perplexity': 30.0,
#  'random_state': 1,
#  'verbose': 0}

# %% [markdown]
# ## PERPLEXITY = 1

# %%
# Sets up t-SNE with perplexity = 1
tsne = TSNE(
    n_components=2,
    perplexity=1,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7faf2b04f740>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# <Axes: >

# %% [markdown]
# ## PERPLEXITY = 2

# %%
# Sets up t-SNE with perplexity = 2
tsne = TSNE(
    n_components=2,
    perplexity=2,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7faef050f880>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# <Axes: >

# %% [markdown]
# ## PERPLEXITY = 5

# %%
# Sets up t-SNE with perplexity = 5
tsne = TSNE(
    n_components=2,
    perplexity=5,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7faef050d260>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# <Axes: >

# %% [markdown]
# ## PERPLEXITY = 10

# %%
# Sets up t-SNE with perplexity = 10
tsne = TSNE(
    n_components=2,
    perplexity=10,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7faee39fbb00>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# <Axes: >

# %% [markdown]
# ## PERPLEXITY = 50

# %%
# Sets up t-SNE with perplexity = 50
tsne = TSNE(
    n_components=2,
    perplexity=50,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7faef00b9c60>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'
# <Axes: >

# %% [markdown]
# # CLEAN UP
#
# - If desired, clear the results with Cell > All Output > Clear.
# - Save your work by selecting File > Save and Checkpoint.
# - Shut down the Python kernel and close the file by selecting File > Close and Halt.
